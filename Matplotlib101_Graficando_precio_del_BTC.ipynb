# %% [markdown]
# <a href="https://colab.research.google.com/github/oniprograma/Matplotlib101/blob/main/Matplotlib101_Graficando_precio_del_BTC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hacemos uso de la página gratiuita de Yahoo. https://finance.yahoo.com/quote/BTC-USD/history/
# Seleccionamos una ventana de tiempo y descargamos los datos

# %%
import matplotlib.pyplot as plt

import pandas as pd

datos = pd.read_csv('/content/BTC-USD.csv')
datos.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2021-05-01  57714.664063  58448.339844  57052.273438  57828.050781
# 1  2021-05-02  57825.863281  57902.593750  56141.906250  56631.078125
# 2  2021-05-03  56620.273438  58973.308594  56590.871094  57200.292969
# 3  2021-05-04  57214.179688  57214.179688  53191.425781  53333.539063
# 4  2021-05-05  53252.164063  57911.363281  52969.054688  57424.007813
#
#       Adj Close       Volume
# 0  57828.050781  42836427360
# 1  56631.078125  38177405335
# 2  57200.292969  51713139031
# 3  53333.539063  68564706967
# 4  57424.007813  69241316747

# %%
fechas = datos['Date'].to_list()
apertura = datos['Open'].to_list()

# %%
plt.plot(fechas,apertura,'-', label='Precio')
 
plt.xlabel('tiempo')
plt.ylabel('Precio')
plt.title('Cambio del Bitcoin')
plt.legend()
plt.show()

# %%
import matplotlib.dates as mdates
import numpy as np

fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))

ax1.plot(fechas,apertura, '-', label='Precio')

ax1.set_xticks(np.arange(0, len(fechas), 90))
plt.xlabel('Minuto')
plt.ylabel('Precio')
plt.title('Cambio del BTC')
plt.legend()

plt.show()
